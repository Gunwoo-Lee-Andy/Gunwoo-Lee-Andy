# %% [markdown]
# ### 하이퍼 파라미터 설정

# %%
import os, re
import random, math
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# ### 데이터 준비하기

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-0618-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person399_virus_793.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### 모델링 (CNN)

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ### 데이터 불균형 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ### 모델훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 91s 233ms/step - loss: 0.4628 - accuracy: 0.7651 - precision: 0.9330 - recall: 0.7292 - val_loss: 0.6802 - val_accuracy: 0.7317 - val_precision: 0.7317 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.2481 - accuracy: 0.9092 - precision: 0.9662 - recall: 0.9086 - val_loss: 1.2075 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 59s 228ms/step - loss: 0.1997 - accuracy: 0.9288 - precision: 0.9737 - recall: 0.9295 - val_loss: 0.5959 - val_accuracy: 0.7375 - val_precision: 0.7367 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.1682 - accuracy: 0.9456 - precision: 0.9810 - recall: 0.9452 - val_loss: 0.2260 - val_accuracy: 0.9106 - val_precision: 0.9970 - val_recall: 0.8804
# Epoch 5/25
# 261/261 [==============================] - 60s 231ms/step - loss: 0.1290 - accuracy: 0.9516 - precision: 0.9857 - recall: 0.9486 - val_loss: 0.1292 - val_accuracy: 0.9442 - val_precision: 0.9314 - val_recall: 0.9974
# Epoch 6/25
# 261/261 [==============================] - 62s 237ms/step - loss: 0.1448 - accuracy: 0.9379 - precision: 0.9831 - recall: 0.9337 - val_loss: 0.1674 - val_accuracy: 0.9365 - val_precision: 0.9929 - val_recall: 0.9201
# Epoch 7/25
# 261/261 [==============================] - 66s 253ms/step - loss: 0.1610 - accuracy: 0.9439 - precision: 0.9852 - recall: 0.9381 - val_loss: 0.2471 - val_accuracy: 0.8817 - val_precision: 0.8618 - val_recall: 0.9987
# Epoch 8/25
# 261/261 [==============================] - 58s 222ms/step - loss: 0.1137 - accuracy: 0.9575 - precision: 0.9890 - recall: 0.9538 - val_loss: 0.0814 - val_accuracy: 0.9654 - val_precision: 0.9973 - val_recall: 0.9556
# Epoch 9/25
# 261/261 [==============================] - 58s 222ms/step - loss: 0.1164 - accuracy: 0.9628 - precision: 0.9860 - recall: 0.9634 - val_loss: 0.2793 - val_accuracy: 0.8913 - val_precision: 1.0000 - val_recall: 0.8517
# Epoch 10/25
# 261/261 [==============================] - 57s 220ms/step - loss: 0.1273 - accuracy: 0.9543 - precision: 0.9844 - recall: 0.9535 - val_loss: 0.1564 - val_accuracy: 0.9346 - val_precision: 0.9986 - val_recall: 0.9122
# Epoch 11/25
# 261/261 [==============================] - 57s 218ms/step - loss: 0.1109 - accuracy: 0.9569 - precision: 0.9898 - recall: 0.9525 - val_loss: 0.0630 - val_accuracy: 0.9750 - val_precision: 0.9920 - val_recall: 0.9737
# Epoch 12/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.1050 - accuracy: 0.9578 - precision: 0.9903 - recall: 0.9527 - val_loss: 0.0521 - val_accuracy: 0.9808 - val_precision: 0.9781 - val_recall: 0.9961
# Epoch 13/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.0964 - accuracy: 0.9613 - precision: 0.9879 - recall: 0.9603 - val_loss: 0.0539 - val_accuracy: 0.9817 - val_precision: 0.9947 - val_recall: 0.9804
# Epoch 14/25
# 261/261 [==============================] - 57s 220ms/step - loss: 0.0997 - accuracy: 0.9596 - precision: 0.9929 - recall: 0.9532 - val_loss: 0.0391 - val_accuracy: 0.9817 - val_precision: 0.9973 - val_recall: 0.9777
# Epoch 15/25
# 261/261 [==============================] - 58s 222ms/step - loss: 0.0897 - accuracy: 0.9706 - precision: 0.9940 - recall: 0.9668 - val_loss: 0.1376 - val_accuracy: 0.9433 - val_precision: 1.0000 - val_recall: 0.9227
# Epoch 16/25
# 261/261 [==============================] - 58s 222ms/step - loss: 0.0867 - accuracy: 0.9695 - precision: 0.9925 - recall: 0.9660 - val_loss: 0.0542 - val_accuracy: 0.9721 - val_precision: 0.9986 - val_recall: 0.9633
# Epoch 17/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.1023 - accuracy: 0.9650 - precision: 0.9913 - recall: 0.9619 - val_loss: 0.0318 - val_accuracy: 0.9865 - val_precision: 0.9947 - val_recall: 0.9869
# Epoch 18/25
# 261/261 [==============================] - 58s 222ms/step - loss: 0.0916 - accuracy: 0.9649 - precision: 0.9900 - recall: 0.9626 - val_loss: 0.1360 - val_accuracy: 0.9538 - val_precision: 0.9418 - val_recall: 0.9987
# Epoch 19/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.0657 - accuracy: 0.9769 - precision: 0.9942 - recall: 0.9745 - val_loss: 0.6984 - val_accuracy: 0.8154 - val_precision: 0.7987 - val_recall: 1.0000
# Epoch 20/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.1170 - accuracy: 0.9596 - precision: 0.9897 - recall: 0.9558 - val_loss: 0.0454 - val_accuracy: 0.9856 - val_precision: 0.9895 - val_recall: 0.9908
# Epoch 21/25
# 261/261 [==============================] - 57s 220ms/step - loss: 0.0795 - accuracy: 0.9682 - precision: 0.9943 - recall: 0.9633 - val_loss: 0.1109 - val_accuracy: 0.9654 - val_precision: 0.9595 - val_recall: 0.9948
# Epoch 22/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.0922 - accuracy: 0.9659 - precision: 0.9916 - recall: 0.9625 - val_loss: 0.1728 - val_accuracy: 0.9288 - val_precision: 0.9928 - val_recall: 0.9093
# Epoch 23/25
# 261/261 [==============================] - 58s 222ms/step - loss: 0.1198 - accuracy: 0.9486 - precision: 0.9876 - recall: 0.9430 - val_loss: 0.3661 - val_accuracy: 0.8365 - val_precision: 0.9983 - val_recall: 0.7791
# Epoch 24/25
# 261/261 [==============================] - 57s 220ms/step - loss: 0.1068 - accuracy: 0.9594 - precision: 0.9918 - recall: 0.9529 - val_loss: 0.0629 - val_accuracy: 0.9750 - val_precision: 0.9933 - val_recall: 0.9725
# Epoch 25/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.0963 - accuracy: 0.9642 - precision: 0.9933 - recall: 0.9593 - val_loss: 0.1201 - val_accuracy: 0.9673 - val_precision: 0.9619 - val_recall: 0.9948

# %% [markdown]
# ### 결과 및 시각화

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 6s 145ms/step - loss: 1.5627 - accuracy: 0.7051 - precision: 0.6794 - recall: 1.0000
# Loss: 1.562700867652893,
# Accuracy: 0.7051281929016113,
# Precision: 0.6794425249099731,
# Recall: 1.0

# %% [markdown]
# ### 성능개선

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        #tf.keras.layers.Dropout(dropout_rate)    # dropout을 제거해보겠습니다.
    ])
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

# %%
with tf.device('/GPU:0'):
    model = build_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=METRICS)

# %%
EPOCHS = 10

with tf.device('/GPU:0'):
    history = model.fit(
        train_ds_a,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds_a,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )

# %%
fig, ax = plt.subplots(1, 4, figsize=(16, 4))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_'+met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)    # dropout을 사용합니다.
    ])
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

# %%
with tf.device('/GPU:0'):
    model = build_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=METRICS)

# %%
EPOCHS = 10

with tf.device('/GPU:0'):
    history = model.fit(
        train_ds_a,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds_a,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )

# %%
fig, ax = plt.subplots(1, 4, figsize=(16, 4))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_'+met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)

# %%
### 평가 

#### 1. 먼저 학습시간이 오래걸려 모델을 다양하게 평가해 보지 못했다. 
#### 2. 아직도 모델에 있어서 자유롭지 못한 것 같다.
